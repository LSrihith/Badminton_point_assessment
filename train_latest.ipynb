# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
ROOT_DIR='/content/gdrive/My Drive/project/YOLOV8/Shuttlecock'

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.0/608.0 kB 9.6 MB/s eta 0:00:00
# ...

# %%
import os

from ultralytics import YOLO


# Load a model
model = YOLO("yolov8l.yaml")  # build a new model from scratch

# Use the model
results = model.train(data=os.path.join(ROOT_DIR, "data1.yaml"), epochs=20)  # train the model
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  3    279808  ultralytics.nn.modules.block.C2f             [128, 128, 3, True]
#   3                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   4                  -1  6   2101248  ultralytics.nn.modules.block.C2f             [256, 256, 6, True]
#   5                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   6                  -1  6   8396800  ultralytics.nn.modules.block.C2f             [512, 512, 6, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
# ...

# %%
# import shutil

# source_directory = '/content/runs'
# destination_directory = '/content/gdrive/My Drive/project/YOLOV8/Shuttlecocks3'

# shutil.copytree(source_directory,destination_directory)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-3fb8a6c20dec> in <cell line: 6>()
#       4 destination_directory = '/content/gdrive/My Drive/project/YOLOV8/Shuttlecocks3'
#       5
# ----> 6 shutil.copytree(source_directory, destination_directory)
#
# /usr/lib/python3.10/shutil.py in copytree(src, dst, symlinks, ignore, copy_function, ignore_dangling_symlinks, dirs_exist_ok)
#     554     """
#     555     sys.audit("shutil.copytree", src, dst)
# --> 556     with os.scandir(src) as itr:
#     557         entries = list(itr)
#     558     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/runs'

# %%
# !yolo task=detect mode=predict model=/content/gdrive/MyDrive/project/YOLOV8/Shuttlecocks3/detect/train/weights/best.pt conf=0.55 source=/content/gdrive/MyDrive/project/YOLOV8/photos
# Out:
# Ultralytics YOLOv8.0.142 🚀 Python-3.10.6 torch-2.0.1+cu118 CPU (AMD EPYC 7B12)
# YOLOv8l summary (fused): 268 layers, 43607379 parameters, 0 gradients
#
# image 1/7 /content/gdrive/MyDrive/project/YOLOV8/photos/1.jpg: 640x640 (no detections), 2183.1ms
# image 2/7 /content/gdrive/MyDrive/project/YOLOV8/photos/2.jpg: 640x640 (no detections), 2528.4ms
# image 3/7 /content/gdrive/MyDrive/project/YOLOV8/photos/3.jpg: 640x640 (no detections), 2044.3ms
# image 4/7 /content/gdrive/MyDrive/project/YOLOV8/photos/4.jpg: 640x640 1 Shuttlecock, 2012.4ms
# image 5/7 /content/gdrive/MyDrive/project/YOLOV8/photos/5.jpg: 640x640 1 Shuttlecock, 2024.2ms
# image 6/7 /content/gdrive/MyDrive/project/YOLOV8/photos/6.jpg: 640x640 (no detections), 2022.3ms
# image 7/7 /content/gdrive/MyDrive/project/YOLOV8/photos/7.jpg: 640x640 1 Shuttlecock, 2415.8ms
# Speed: 2.3ms preprocess, 2175.8ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict

# %%
# !cp -r /content/runs/detect/predict /content/gdrive/MyDrive/project/YOLOV8/output

# %%
# !yolo task=detect mode=predict model=/content/gdrive/MyDrive/project/YOLOV8/Shuttlecocks3/detect/train/weights/best.pt conf=0.2 source=/content/gdrive/MyDrive/project/YOLOV8/photos/12345.mp4
# Out:
# Ultralytics YOLOv8.0.142 🚀 Python-3.10.6 torch-2.0.1+cu118 CPU (AMD EPYC 7B12)
# YOLOv8l summary (fused): 268 layers, 43607379 parameters, 0 gradients
#
# video 1/1 (1/468) /content/gdrive/MyDrive/project/YOLOV8/photos/12345.mp4: 384x640 (no detections), 1337.6ms
# video 1/1 (2/468) /content/gdrive/MyDrive/project/YOLOV8/photos/12345.mp4: 384x640 (no detections), 1241.4ms
# video 1/1 (3/468) /content/gdrive/MyDrive/project/YOLOV8/photos/12345.mp4: 384x640 (no detections), 1222.2ms
# video 1/1 (4/468) /content/gdrive/MyDrive/project/YOLOV8/photos/12345.mp4: 384x640 (no detections), 1225.9ms
# video 1/1 (5/468) /content/gdrive/MyDrive/project/YOLOV8/photos/12345.mp4: 384x640 (no detections), 1214.2ms
# video 1/1 (6/468) /content/gdrive/MyDrive/project/YOLOV8/photos/12345.mp4: 384x640 (no detections), 1225.1ms
# video 1/1 (7/468) /content/gdrive/MyDrive/project/YOLOV8/photos/12345.mp4: 384x640 (no detections), 1534.1ms
# ...

# %%
# !cp -r /content/runs/detect/predict10 /content/gdrive/MyDrive/project/YOLOV8/output

# %%
# !yolo task=detect mode=predict model=/content/gdrive/MyDrive/project/YOLOV8/Shuttlecocks3/detect/train/weights/best.pt conf=0.01 source=/content/gdrive/MyDrive/project/YOLOV8/photos/11.jpeg
# Out:
# Ultralytics YOLOv8.0.142 🚀 Python-3.10.6 torch-2.0.1+cu118 CPU (AMD EPYC 7B12)
# YOLOv8l summary (fused): 268 layers, 43607379 parameters, 0 gradients
#
# image 1/1 /content/gdrive/MyDrive/project/YOLOV8/photos/11.jpeg: 576x640 1 Shuttlecock, 1877.4ms
# Speed: 2.0ms preprocess, 1877.4ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
# Results saved to runs/detect/predict8

# %%
# !cp -r /content/runs/detect/predict8 /content/gdrive/MyDrive/project/YOLOV8/output
